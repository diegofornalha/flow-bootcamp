# %% [markdown]
# 🤔 O que é Flow?
#
# Flow é uma nova rede blockchain criada especificamente para ser usada por um grande público. A ideia é que ela seja mais fácil de usar do que as outras redes blockchain existentes, que podem ser bastante complicadas para as pessoas que não estão familiarizadas com elas.
#
# Por exemplo, se você tem um aplicativo web3 que você gosta muito, como um site de negociação de NFTs ou um site de negociação como UniSwap, é possível que sua mãe ou avó tenha dificuldade em usá-la.
#
# Elas poderiam precisar baixar uma carteira, configurar uma "frase secreta" e comprar criptomoedas apenas para experimentar o aplicativo. Isso pode ser bastante complicado e desencorajador as pessoas que não estão familiarizadas com o mundo das criptomoedas.
#
# Com a Flow a situação mudou. Tudo nele foi projetado para ser escalável, ou seja, para ser usado por um grande número de pessoas. Por exemplo, sua avó pode começar a usar qualquer aplicativo Flow em apenas 10 segundos, bastando para isso usar o endereço de e-mail dela.
#
# Não é preciso configurar uma carteira ou fazer qualquer outra coisa complicada. Além disso, as taxas de transação são subsidiadas (gratuitas para iniciantes) mesmo na rede principal, o que significa que ela não precisará gastar dinheiro para usar os aplicativos Flow.
#
# ![https://hackmd.io/_uploads/Hk0T5g7qc.png](https://hackmd.io/_uploads/Hk0T5g7qc.png)
#
# Vamos dedicar bastante tempo neste projeto para mergulhar na Flow e você terá muita oportunidade de aprender sobre o que é a Flow e como ela funciona. Não se preocupe, vamos falar sobre coisas como as baixas taxas de gás ds Flow e o fato de ser muito rápida. Eu não quero que percamos muito tempo com teoria, então vamos focar na prática.
#
# Eu sei que pode ser tentador ir para o YouTube para aprender mais sobre o assunto, mas eu sugiro que deixemos isso para depois de terminarmos este projeto. Prometo que sua pesquisa fará muito mais sentido quando tivermos uma base sólida neste projeto. É claro que é útil ter uma compreensão básica de alguns conceitos e uma visão geral de como as coisas funcionam na Flow, então vamos nos aprofundar nisso.
#
# ### 👩‍💻 Contratos inteligentes
#
# Os contratos inteligentes de flow são muito parecidos com outros blockchains. Aqui está uma recapitulação das partes que você **precisa** conhecer.
#
# ![https://hackmd.io/_uploads/SyT0Ow3uc.png](https://hackmd.io/_uploads/SyT0Ow3uc.png)
#
# [Origem da imagem](https://docs.onflow.org/dapp-development/flow-dapp-anatomy/?utm_source=buildspace.so&utm_medium=buildspace_project)
#
# Para quem ainda não está familiarizado, a maioria dos usuários começa a interagir com o blockchain através de um cliente, que pode ser um site ou um aplicativo móvel. Para poder realizar transações no blockchain, é preciso conectar uma carteira à esses clientes.
#
# A conta do usuário, que armazena informações como saldo e histórico de transações, fica armazenada na blockchain e pode se comunicar com contratos inteligentes, que são programas que podem realizar ações específicas como comprar tokens ou NFTs (non-fungible tokens, ou tokens não-fungíveis, que são itens únicos e inestimáveis no blockchain).
#
# Para facilitar a comunicação entre esses clientes e contratos inteligentes, existe o pacote chamado Flow Client Library (FCL). Ele é parecido com outros pacotes como o Ethers.js ou o Web3js, mas é considerado mais fácil de usar.
#
# Com o FCL, não é preciso se preocupar em escrever códigos de comunicação diferentes para cada tipo de carteira, basta escrever um código que funcionará para todas as carteiras Flow.
#
# Se você ainda não está familiarizado com contratos inteligentes, pense neles como máquinas de venda automática que só aceitam cheques. Eles só existem no mundo virtual da blockchain, então é como se fossem máquinas de venda automática imaginárias.
#
# Eles só realizam ações específicas quando são acionados por uma conta na blockchain, e suas ações são determinadas pelo código que foi escrito para eles.
#
# ![fluxo.png](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/0ae0494d-0301-49ff-b590-fb044e369deb/fluxo.png)
#
# O atendente, que está no formato de um aplicativo, vai te perguntar o que você quer. Depois de informar o que deseja, ele vai gerar um cheque de transação para você. Para assinar essa transação, você precisará usar uma "caneta digital", que pode ser um aplicativo de carteira, como o Blocto ou Lilico. Depois de assinar a transação, basta enviá-la para a máquina de venda, que está na blockchain.
#
# Essa máquina de venda é um contrato inteligente, ou seja, um conjunto de regras e instruções que são armazenadas na blockchain e que são executadas quando uma transação é enviada para ela. Nesse caso específico, a transação pode incluir instruções para retirar alguns tokens de você, em troca, entregar uma coca. Tudo isso acontecerá automaticamente, desde que a transação siga as regras.
#
# ### 🏦 Contas
#
# O Flow é um sistema que utiliza uma estrutura de dados especial chamada "Contas" para armazenar informações. Essas contas são semelhantes às contas de e-mail ou de armazenamento em nuvem, como o Dropbox ou o Google Drive. As contas do Flow têm credenciais de acesso, como um login e uma senha, e servem para armazenar coisas como arquivos e texto. Em resumo, uma conta da Flow é uma espécie de "caixa virtual” que pode ser usada para armazenar e acessar informações.
#
# Esta é a estrutura de uma conta do Flow:
#
# ![https://hackmd.io/_uploads/rklMwaau5.png](https://hackmd.io/_uploads/rklMwaau5.png)
#
# [Origem da imagem](https://youtu.be/pRz7EzrWchs?t=37?utm_source=buildspace.so&utm_medium=buildspace_project)
#
# As contas do Flow são como contas de usuário dentro do sistema, cada uma com seu próprio espaço de armazenamento e sistema de arquivos.
#
# A área de armazenamento de contrato é onde ficam os contratos inteligentes, que são como programas que rodam na Flow. É possível ter vários contratos inteligentes em uma mesma conta e atualizar suas interfaces facilmente.
#
# O sistema de arquivos das contas é como uma estrutura de pastas e arquivos, e existem três tipos de pastas disponíveis:
#
# **`/storage/`**, **`/private/`** e **`/public/`**.
#
# A pasta **`/storage/`** é acessível apenas pelo proprietário da conta, a pasta **`/private/`** é acessível pelo proprietário e pelas contas permitidas, e a pasta **`/public/`** é acessível por qualquer pessoa na rede.
#
# ![web (1).png](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/f287eb87-3c55-4722-b376-3f1a47ce7483/web_(1).png)
#
# Infelizmente, não é possível armazenar coisas físicas, como latas de Coca, nas pastas de armazenamento das contas Flow. No entanto, é possível armazenar qualquer tipo de estrutura de dados em um contrato, seja uma string simples ou um recurso mais complexo, como um cofre que armazena saldos de tokens ou um mapeamento de NFTs e seus respectivos proprietários.
#
# Enfim, qualquer informação que você queira armazenar e manipular com contratos inteligentes pode ser armazenada nas pastas de armazenamento. Por exemplo, se você quiser armazenar a mensagem "Olá mundo", basta criar uma variável com esse valor e ela será armazenada na pasta de armazenamento da sua conta.
#
# ### 💚 Cadence
#
# O Flow é uma plataforma blockchain que vem com uma nova linguagem de programação chamada Cadence. A sintaxe da linguagem foi inspirada em outras linguagens populares, como Swift e Rust, e foi projetada para ser clara e fácil de ler.
#
# Mas por que foi criada uma nova linguagem para a programação blockchain? Bem, a programação blockchain é um espaço totalmente novo e diferente do que já conhecíamos. As linguagens de programação existentes foram criadas para programar computadores tradicionais, privados e sem estado. No entanto, as blockchains são distribuídas, com estado e públicas, o que significa que as mesmas primitivas de linguagem não se aplicam mais. É como tentar usar um forno de pedra antigo para cozinhar macarrão de microondas - eles são coisas completamente diferentes e precisam de soluções diferentes.
#
# Na história da programação, sempre que surgiram novos espaços ou necessidades, novas linguagens de programação surgiram para atender a essas necessidades. Quando os computadores se tornaram comuns, precisávamos de código portátil que pudesse rodar em qualquer hardware - e foi assim que nasceu o C. Quando as interfaces gráficas começaram a ficar populares, a programação orientada a objetos de Java se tornou uma ótima opção. Com o surgimento de aplicativos da web que faziam scripts do lado do cliente, usamos JavaScript. E agora, com as necessidades específicas da programação blockchain, temos o Cadence.
#
# ### 🔒 Programação Orientada a Recursos
#
# Solidity é uma linguagens de programação que é usada para criar contratos inteligentes na blockchain. No entanto, existe um problema com essa e outras linguagens similares: os "recursos escassos" são apenas estruturas de dados, o que significa que, se um contrato inteligente não inclui guardas e verificações, qualquer pessoa pode alterar a propriedade de um ativo alterando uma estrutura de dados, como um mapeamento. Isso significa que, mesmo que você possua NFTs (ativos não fungíveis), isso é apenas porque o contrato diz isso. Se o contrato não for construído corretamente, alguém pode alterar quem é o proprietário sem sua permissão.
#
# Para resolver esse problema, a Cadence introduziu a Programação Orientada a Recursos. Essa decisão não foi tomada de forma aleatória; muita pesquisa foi feita antes de chegar a essa conclusão. Sem entrar em teoria muito profunda, tudo o que você precisa saber é que objetos em blockchains têm dois requisitos principais:
#
# 1. Eles devem ser controlavelmente escassos
# 2. Seu acesso deve ser controlado e aplicado
#
# Em resumo, os recursos são itens que devem ser controlados de forma a garantir que existam em quantidades limitadas e que o acesso a eles seja restrito.
#
# Para atender a esses requisitos, a Cadence utiliza "recursos". Quando fazemos de algo um recurso, ele deve seguir estas regras:
#
# 1. **Cada Recurso existe exatamente em um lugar a qualquer momento**
#
#     Os recursos não podem ser duplicados ou excluídos acidentalmente, seja por erro de programação ou código malicioso.
#
# 2. **A propriedade de um Recurso é definida por onde ele está armazenado**
#
#     Não há um livro-razão central que precise ser consultado para determinar a propriedade.
#
# 3. **O acesso aos métodos em um Recurso é limitado ao proprietário**
#
#     Por exemplo, apenas o proprietário de um CryptoKitty pode iniciar uma operação de criação que levará ao nascimento de um novo Kitty.
#
#
# Cadence utiliza esses recursos para assegurar que eles sejam controláveis e aplicados de forma apropriada. Isso é feito garantindo que cada recurso exista exatamente em um lugar a qualquer momento, que a propriedade de um recurso seja definida pelo lugar onde ele está armazenado e que o acesso aos métodos de um recurso seja limitado ao seu proprietário.
#
# Se você está trabalhando com o Cadence, é importante saber que as regras do código são aplicadas tanto durante a compilação quanto durante a execução. Isso significa que, se você escrever um código que tenta fazer algo que você não tem permissão de fazer, como transferir um NFT sem verificar se você tem a permissão adequada, a transação simplesmente não vai acontecer. A blockchain vai cancelar a sua transação e dizer "Ei, você está tentando fazer algo que não tem permissão, saia daqui".
#
# Outra coisa importante a saber é que os recursos só podem existir em um único local e não podem ser copiados ou perdidos devido a erros de codificação. Em vez de registrar a propriedade de um ativo de forma independente, os recursos vinculam a propriedade de um ativo diretamente à conta que o possui, armazenando os recursos na memória da conta.
#
# Mas aqui está a parte legal: como os recursos são apenas tipos de dados, eles podem "possuir" outros recursos. Então, se você estiver criando uma versão "on-chain" de Pokémon, por exemplo, o seu Pikachu pode "possuir" itens como pedras de evolução ou power-ups.
#
# Se tudo isso ainda estiver um pouco confuso, não se preocupe! Quando começarmos a escrever código, as coisas vão ficar mais claras. Por enquanto, pense no Cadence como um mundo onde as leis da física não permitem que você roube coisas.
#
# Chega de ler, VAMOS PRESSIONAR ALGUNS BOTÕES DO NOSSO TECLADO!
